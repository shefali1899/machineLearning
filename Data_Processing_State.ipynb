# %%
import pandas as pd

# %%
#Convert json string to a pandas object and print the first six lines of the pandas dataframe
df = pd.read_json('business.json', lines=True)
df.head(10)
# Out:
#                                address  \
# 0                      691 Richmond Rd
# 1                       2824 Milton Rd
# 2                  337 Danforth Avenue
# 3  7702 E Doubletree Ranch Rd, Ste 300
# 4                       4719 N 20Th St
# 5                  2017 E Camelback Rd
# 6              4425 N 24th St, Ste 125
# 7                       5770 Butler St
# 8                   3220 Washington Rd
# 9            1425 S Higley Rd, Ste 103
#
#                                           attributes             business_id  \
# 0  {'WheelchairAccessible': True, 'RestaurantsPri...  YDf95gJZaq05wvo7hTQbbQ
# 1  {'NoiseLevel': 'average', 'RestaurantsReservat...  mLwM-h2YhXl2NCgdS84_Bw
# 2  {'WheelchairAccessible': True, 'BusinessParkin...  v2WhjAB3PIBA8J8VxG3wEg
# 3                                                 {}  CVtCbSB1zUcUWg-9TNGTuQ
# 4  {'NoiseLevel': 'quiet', 'RestaurantsReservatio...  duHFBe87uNSXImQmvBh87Q
# ...

# %%
#Drop all columns except business_id, latitude, longitude, review_count, stars

labels = ['address', 'attributes', 'categories', 'city', 'hours', 'is_open', 'name',
         'neighborhood', 'postal_code']
df1 = df.drop(labels, axis=1)
df1.head(10)
# Out:
#               business_id   latitude   longitude  review_count  stars state
# 0  YDf95gJZaq05wvo7hTQbbQ  41.541716  -81.493116            17    2.0    OH
# 1  mLwM-h2YhXl2NCgdS84_Bw  35.236870  -80.741976             4    4.5    NC
# 2  v2WhjAB3PIBA8J8VxG3wEg  43.677126  -79.353285             7    4.5    ON
# 3  CVtCbSB1zUcUWg-9TNGTuQ  33.565082 -111.916400             3    3.0    AZ
# 4  duHFBe87uNSXImQmvBh87Q  33.505928 -112.038847            10    4.5    AZ
# 5  uUEMrhJiL1a1pCA_I1SU7Q  33.508068 -112.037552            35    5.0    AZ
# 6  2eJEUJIP54tex7T9YOcLSw  33.502848 -112.012696            19    5.0    AZ
# 7  fEylCY3UEH8YJ0Xa7lu6lA  40.485939  -79.943727            16    2.5    PA
# 8  kFtuYklkAIlmYw8RZAieGw  40.290498  -80.110021             7    5.0    PA
# 9  NqiQdFa93wzUJGo29NbTPQ  33.324539 -111.720449             8    5.0    AZ

# %%
#Export to a csv file 
df1.to_csv("rest_state_data.csv")
